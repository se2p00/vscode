# %%
# CSV 파일 전처리
# 엑셀로 만든 CSV 파일 인코딩을 엑셀에서 UTF-8로 저장해도 UTF-8 이나 EUC-KR 로 인코딩할 때 에러 발생
# CP949로 인코딩 성공

def clean_file(fileName, save=False, replace=False):
    if replace:
        save = True
    [fname, ftype] = str(fileName).split('.')
    import pandas as pd
    try:
        if ftype == 'csv':
            df = pd.read_csv(fileName)
        elif ftype == 'xlsx':
            df = pd.read_excel(fileName)
        df = col_check(df)

        if not replace:
            fileName = fname+'_cleaned.'+ftype

        if save:
            if ftype == 'csv':
                df.to_csv(fileName, index=False)
            elif ftype == 'xlsx':
                df.to_excel(fileName, index=False)
        return df

    except UnicodeDecodeError:
        df = pd.read_csv(fileName, encoding='CP949')
        df = col_check(df)
        return df

    except Exception as ex:
        print('%s' % (ex))


def col_check(df):
    colList = list(df.columns)
    for col in colList:
        if "Unnamed:" in col:  # 이름이 없는 칼럼 삭제
            df = df.drop(col, axis=1)
            colList = list(df.columns)
    newcolList = []
    for col in colList:
        if "\t" in col:
            new = str(col).replace('\t', '')
        else:
            new = col
        newcolList.append(new)
    df.columns = newcolList
    return df


fileName = '2006_2022.csv'
df = clean_file(fileName)
df
# Out:
# C:\Users\se2p0\AppData\Local\Temp\ipykernel_10648\3195701596.py:13: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fileName)
#         구분          일자    품목구분         품목코드                         품목명
# 0       본사  2006-01-02    [제품]   FBP-000001      TFB-F19DS 1Φ 220V 60HZ  \
# 1       본사  2006-01-02    [제품]   FBP-000005      TFB-G25DS 1Φ 220V 60HZ
# 2       본사  2006-01-02    [제품]   FBP-000009      TFB-F28FS 1Φ 220V 60HZ
# 3       본사  2006-01-02    [제품]   FBP-000030  TFB-G39HT 3Φ 220／380V 60HZ
# 4       본사  2006-01-02   [원재료]  FBOM-000017            MOTOR ASS′Y 60Hz
# ...     ..         ...     ...          ...                         ...
# 508595  영남  2022-12-31  [무형상품]    2015-0100                        인센티브
# 508596  영남  2022-12-31  [무형상품]    2015-0100                        인센티브
# 508597  영남  2022-12-31  [무형상품]    2015-0100                        인센티브
# 508598  영남  2022-12-31  [무형상품]    2015-0100                        인센티브
# 508599  영남  2022-12-31  [무형상품]    2015-0100                        인센티브
#
#                               최신 품목명         규격  수량   단위      단가  ...
# 0           ●TFB-F19DS 1Φ 220V, 60HZ  TFB-F19DS  10   EA   57000  ...  \
# 1           ●TFB-G25DS 1Φ 220V, 60HZ  TFB-G25DS  15   EA   95000  ...
# 2           ●TFB-F28FS 1Φ 220V, 60HZ  TFB-F28FS  15   EA  117000  ...
# 3       ●TFB-G39HT 3Φ 220/380V, 60HZ  TFB-G39HT   4   EA  329000  ...
# 4                   MOTOR ASS′Y 60Hz      G39HT   1   EA       0  ...
# ...                              ...        ...  ..  ...     ...  ...
# 508595                          인센티브        NaN  -1  NaN  300900  ...
# 508596                          인센티브        NaN  -1  NaN  345800  ...
# 508597                          인센티브        NaN  -1  NaN  312300  ...
# 508598                          인센티브        NaN  -1  NaN  378600  ...
# 508599                          인센티브        NaN  -1  NaN  301000  ...
#
#                    거래처  거래처그룹1 거래처그룹2  담당자    개설연도       지역구분 인센가입    품목그룹1
# 0       (X)중앙상사->21689  영업_대리점  영업_산업  윤형설  2006이전   전라남도 순천시   적용  10_시로코팬  \
# 1       (X)중앙상사->21689  영업_대리점  영업_산업  윤형설  2006이전   전라남도 순천시   적용  10_시로코팬
# 2       (X)중앙상사->21689  영업_대리점  영업_산업  윤형설  2006이전   전라남도 순천시   적용  10_시로코팬
# 3       (X)중앙상사->21689  영업_대리점  영업_산업  윤형설  2006이전   전라남도 순천시   적용  10_시로코팬
# 4              (Y)대한환기  영업_대리점  영업_산업  박종호  2006이전   경상남도 마산시   적용      NaN
# ...                ...     ...    ...  ...     ...        ...  ...      ...
# 508595  대성스텐／대성닥트／대성물산  영업_대리점  영업_산업  박종호    2014     경남 거제시   적용    품X_비용
# 508596          신성공조환기  영업_대리점  영업_산업  박종호    2007   경상남도 진주시   적용    품X_비용
# 508597           삼화송풍기  영업_대리점  영업_산업  박종호    2021   대구광역시 중구  NaN    품X_비용
# 508598           태광에어텍  영업_대리점  영업_산업  박종호    2013  부산광역시 강서구   적용    품X_비용
# 508599             동력사  영업_대리점  영업_산업  박종호    2008  부산광역시 사상구  NaN    품X_비용
#
#             품목그룹2 인센품목
# 0       A2_소형시로코팬    Y
# 1       A2_소형시로코팬    Y
# 2       A2_소형시로코팬    Y
# 3       A3_대형시로코팬    Y
# 4             NaN  NaN
# ...           ...  ...
# 508595  품X90_기타비용    N
# 508596  품X90_기타비용    N
# 508597  품X90_기타비용    N
# 508598  품X90_기타비용    N
# 508599  품X90_기타비용    N
#
# [508600 rows x 23 columns]

# %%
sales_all = pd.read_sql_table('sales_all', con=engine)
sales_all
# Out:
#         구분          일자    품목구분         품목코드                         품목명
# 0       본사  2006-01-02    [제품]   FBP-000001      TFB-F19DS 1Φ 220V 60HZ  \
# 1       본사  2006-01-02    [제품]   FBP-000005      TFB-G25DS 1Φ 220V 60HZ
# 2       본사  2006-01-02    [제품]   FBP-000009      TFB-F28FS 1Φ 220V 60HZ
# 3       본사  2006-01-02    [제품]   FBP-000030  TFB-G39HT 3Φ 220／380V 60HZ
# 4       본사  2006-01-02   [원재료]  FBOM-000017            MOTOR ASS′Y 60Hz
# ...     ..         ...     ...          ...                         ...
# 508595  영남  2022-12-31  [무형상품]    2015-0100                        인센티브
# 508596  영남  2022-12-31  [무형상품]    2015-0100                        인센티브
# 508597  영남  2022-12-31  [무형상품]    2015-0100                        인센티브
# 508598  영남  2022-12-31  [무형상품]    2015-0100                        인센티브
# 508599  영남  2022-12-31  [무형상품]    2015-0100                        인센티브
#
#                               최신 품목명         규격  수량    단위      단가  ...
# 0           ●TFB-F19DS 1Φ 220V, 60HZ  TFB-F19DS  10    EA   57000  ...  \
# 1           ●TFB-G25DS 1Φ 220V, 60HZ  TFB-G25DS  15    EA   95000  ...
# 2           ●TFB-F28FS 1Φ 220V, 60HZ  TFB-F28FS  15    EA  117000  ...
# 3       ●TFB-G39HT 3Φ 220/380V, 60HZ  TFB-G39HT   4    EA  329000  ...
# 4                   MOTOR ASS′Y 60Hz      G39HT   1    EA       0  ...
# ...                              ...        ...  ..   ...     ...  ...
# 508595                          인센티브       None  -1  None  300900  ...
# 508596                          인센티브       None  -1  None  345800  ...
# 508597                          인센티브       None  -1  None  312300  ...
# 508598                          인센티브       None  -1  None  378600  ...
# 508599                          인센티브       None  -1  None  301000  ...
#
#                    거래처  거래처그룹1 거래처그룹2  담당자    개설연도       지역구분  인센가입    품목그룹1
# 0       (X)중앙상사->21689  영업_대리점  영업_산업  윤형설  2006이전   전라남도 순천시    적용  10_시로코팬  \
# 1       (X)중앙상사->21689  영업_대리점  영업_산업  윤형설  2006이전   전라남도 순천시    적용  10_시로코팬
# 2       (X)중앙상사->21689  영업_대리점  영업_산업  윤형설  2006이전   전라남도 순천시    적용  10_시로코팬
# 3       (X)중앙상사->21689  영업_대리점  영업_산업  윤형설  2006이전   전라남도 순천시    적용  10_시로코팬
# 4              (Y)대한환기  영업_대리점  영업_산업  박종호  2006이전   경상남도 마산시    적용     None
# ...                ...     ...    ...  ...     ...        ...   ...      ...
# 508595  대성스텐／대성닥트／대성물산  영업_대리점  영업_산업  박종호    2014     경남 거제시    적용    품X_비용
# 508596          신성공조환기  영업_대리점  영업_산업  박종호    2007   경상남도 진주시    적용    품X_비용
# 508597           삼화송풍기  영업_대리점  영업_산업  박종호    2021   대구광역시 중구  None    품X_비용
# 508598           태광에어텍  영업_대리점  영업_산업  박종호    2013  부산광역시 강서구    적용    품X_비용
# 508599             동력사  영업_대리점  영업_산업  박종호    2008  부산광역시 사상구  None    품X_비용
#
#             품목그룹2  인센품목
# 0       A2_소형시로코팬     Y
# 1       A2_소형시로코팬     Y
# 2       A2_소형시로코팬     Y
# 3       A3_대형시로코팬     Y
# 4            None  None
# ...           ...   ...
# 508595  품X90_기타비용     N
# 508596  품X90_기타비용     N
# 508597  품X90_기타비용     N
# 508598  품X90_기타비용     N
# 508599  품X90_기타비용     N
#
# [508600 rows x 23 columns]

# %%
# 해당 모듈들이 설치되어 있어야 함
# sqlalchemy, pymssql
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import select
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
from sqlalchemy import text
from sqlalchemy.engine.url import URL
from sqlalchemy.types import NVARCHAR

db_url = {
    'database': "dbo.sales_main",
    'drivername': 'mssql+pymssql',
    'username': 'se2p00',
    'password': 'rmeo9821',
    'host': '192.168.10.27',
    'port': '1433',
    'query': {'charset': 'UTF-8'},  # the key-point setting
}

engine = create_engine(URL(**db_url), echo=True)

# engine = create_engine('mssql+pymssql://se2p00:rmeo9821@FZ_SA_DGKIM/dbo.sales_main', echo=True)
# session 생성
sales_all = pd.read_sql_table('sales_all', con=engine)
sales_all
# Out:
# ---------------------------------------------------------------------------
# MSSQLDatabaseException                    Traceback (most recent call last)
# File src\pymssql\_pymssql.pyx:647, in pymssql._pymssql.connect()
#
# File src\pymssql\_mssql.pyx:2109, in pymssql._mssql.connect()
#
# File src\pymssql\_mssql.pyx:701, in pymssql._mssql.MSSQLConnection.__init__()
#
# File src\pymssql\_mssql.pyx:1818, in pymssql._mssql.maybe_raise_MSSQLDatabaseException()
#
# File src\pymssql\_mssql.pyx:1835, in pymssql._mssql.raise_MSSQLDatabaseException()
#
# MSSQLDatabaseException: (20002, b'DB-Lib error message 20002, severity 9:\nAdaptive Server connection failed (192.168.10.27)\nDB-Lib error message 20002, severity 9:\nAdaptive Server connection failed (192.168.10.27)\n')
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3275, in Engine.raw_connection(self)
#    3254 """Return a "raw" DBAPI connection from the connection pool.
#    3255
#    3256 The returned object is a proxied version of the DBAPI
#    (...)
#    3273
#    3274 """
# -> 3275 return self.pool.connect()
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\pool\base.py:455, in Pool.connect(self)
#     448 """Return a DBAPI connection from the pool.
#     449
#     450 The connection is instrumented such that when its
#    (...)
#     453
#     454 """
# --> 455 return _ConnectionFairy._checkout(self)
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\pool\base.py:1271, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1270 if not fairy:
# -> 1271     fairy = _ConnectionRecord.checkout(pool)
#    1273     if threadconns is not None:
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\pool\base.py:719, in _ConnectionRecord.checkout(cls, pool)
#     718 else:
# --> 719     rec = pool._do_get()
#     721 try:
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:168, in QueuePool._do_get(self)
#     167 except:
# --> 168     with util.safe_reraise():
#     169         self._dec_overflow()
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:166, in QueuePool._do_get(self)
#     165 try:
# --> 166     return self._create_connection()
#     167 except:
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\pool\base.py:396, in Pool._create_connection(self)
#     394 """Called by subclasses to create a new ConnectionRecord."""
# --> 396 return _ConnectionRecord(self)
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\pool\base.py:681, in _ConnectionRecord.__init__(self, pool, connect)
#     680 if connect:
# --> 681     self.__connect()
#     682 self.finalize_callback = deque()
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\pool\base.py:905, in _ConnectionRecord.__connect(self)
#     904 except BaseException as e:
# --> 905     with util.safe_reraise():
#     906         pool.logger.debug("Error on connect(): %s", e)
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\pool\base.py:901, in _ConnectionRecord.__connect(self)
#     900 self.starttime = time.time()
# --> 901 self.dbapi_connection = connection = pool._invoke_creator(self)
#     902 pool.logger.debug("Created new connection %r", connection)
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\engine\create.py:636, in create_engine.<locals>.connect(connection_record)
#     634             return connection
# --> 636 return dialect.connect(*cargs, **cparams)
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\engine\default.py:580, in DefaultDialect.connect(self, *cargs, **cparams)
#     578 def connect(self, *cargs, **cparams):
#     579     # inherits the docstring from interfaces.Dialect.connect
# --> 580     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File src\pymssql\_pymssql.pyx:653, in pymssql._pymssql.connect()
#
# OperationalError: (20002, b'DB-Lib error message 20002, severity 9:\nAdaptive Server connection failed (192.168.10.27)\nDB-Lib error message 20002, severity 9:\nAdaptive Server connection failed (192.168.10.27)\n')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[1], line 26
#      22 engine = create_engine(URL(**db_url), echo=True)
#      24 # engine = create_engine('mssql+pymssql://se2p00:rmeo9821@FZ_SA_DGKIM/dbo.sales_main', echo=True)
#      25 # session 생성
# ---> 26 sales_all = pd.read_sql_table('sales_all', con=engine)
#      27 sales_all
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\pandas\io\sql.py:334, in read_sql_table(table_name, con, schema, index_col, coerce_float, parse_dates, columns, chunksize, dtype_backend)
#     331 if dtype_backend is lib.no_default:
#     332     dtype_backend = "numpy"  # type: ignore[assignment]
# --> 334 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
#     335     if not pandas_sql.has_table(table_name):
#     336         raise ValueError(f"Table {table_name} not found")
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\pandas\io\sql.py:830, in pandasSQL_builder(con, schema, need_transaction)
#     827     raise ImportError("Using URI string without sqlalchemy installed.")
#     829 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 830     return SQLDatabase(con, schema, need_transaction)
#     832 warnings.warn(
#     833     "pandas only supports SQLAlchemy connectable (engine/connection) or "
#     834     "database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 "
#    (...)
#     837     stacklevel=find_stack_level(),
#     838 )
#     839 return SQLiteDatabase(con)
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\pandas\io\sql.py:1537, in SQLDatabase.__init__(self, con, schema, need_transaction)
#    1535     self.exit_stack.callback(con.dispose)
#    1536 if isinstance(con, Engine):
# -> 1537     con = self.exit_stack.enter_context(con.connect())
#    1538 if need_transaction and not con.in_transaction():
#    1539     self.exit_stack.enter_context(con.begin())
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3251, in Engine.connect(self)
#    3228 def connect(self) -> Connection:
#    3229     """Return a new :class:`_engine.Connection` object.
#    3230
#    3231     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3248
#    3249     """
# -> 3251     return self._connection_cls(self)
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\engine\base.py:147, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
# --> 147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#     150         raise
#     151 else:
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2413, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2411 elif should_wrap:
#    2412     assert sqlalchemy_exception is not None
# -> 2413     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2414 else:
#    2415     assert exc_info[1] is not None
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 if connection is None:
#     144     try:
# --> 145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
#     147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3275, in Engine.raw_connection(self)
#    3253 def raw_connection(self) -> PoolProxiedConnection:
#    3254     """Return a "raw" DBAPI connection from the connection pool.
#    3255
#    3256     The returned object is a proxied version of the DBAPI
#    (...)
#    3273
#    3274     """
# -> 3275     return self.pool.connect()
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\pool\base.py:455, in Pool.connect(self)
#     447 def connect(self) -> PoolProxiedConnection:
#     448     """Return a DBAPI connection from the pool.
#     449
#     450     The connection is instrumented such that when its
#    (...)
#     453
#     454     """
# --> 455     return _ConnectionFairy._checkout(self)
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\pool\base.py:1271, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1262 @classmethod
#    1263 def _checkout(
#    1264     cls,
#    (...)
#    1267     fairy: Optional[_ConnectionFairy] = None,
#    1268 ) -> _ConnectionFairy:
#    1270     if not fairy:
# -> 1271         fairy = _ConnectionRecord.checkout(pool)
#    1273         if threadconns is not None:
#    1274             threadconns.current = weakref.ref(fairy)
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\pool\base.py:719, in _ConnectionRecord.checkout(cls, pool)
#     717     rec = cast(_ConnectionRecord, pool._do_get())
#     718 else:
# --> 719     rec = pool._do_get()
#     721 try:
#     722     dbapi_connection = rec.get_connection()
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:168, in QueuePool._do_get(self)
#     166     return self._create_connection()
#     167 except:
# --> 168     with util.safe_reraise():
#     169         self._dec_overflow()
#     170     raise
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     assert exc_value is not None
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#     149     self._exc_info = None  # remove potential circular references
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:166, in QueuePool._do_get(self)
#     164 if self._inc_overflow():
#     165     try:
# --> 166         return self._create_connection()
#     167     except:
#     168         with util.safe_reraise():
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\pool\base.py:396, in Pool._create_connection(self)
#     393 def _create_connection(self) -> ConnectionPoolEntry:
#     394     """Called by subclasses to create a new ConnectionRecord."""
# --> 396     return _ConnectionRecord(self)
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\pool\base.py:681, in _ConnectionRecord.__init__(self, pool, connect)
#     679 self.__pool = pool
#     680 if connect:
# --> 681     self.__connect()
#     682 self.finalize_callback = deque()
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\pool\base.py:905, in _ConnectionRecord.__connect(self)
#     903     self.fresh = True
#     904 except BaseException as e:
# --> 905     with util.safe_reraise():
#     906         pool.logger.debug("Error on connect(): %s", e)
#     907 else:
#     908     # in SQLAlchemy 1.4 the first_connect event is not used by
#     909     # the engine, so this will usually not be set
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     assert exc_value is not None
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#     149     self._exc_info = None  # remove potential circular references
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\pool\base.py:901, in _ConnectionRecord.__connect(self)
#     899 try:
#     900     self.starttime = time.time()
# --> 901     self.dbapi_connection = connection = pool._invoke_creator(self)
#     902     pool.logger.debug("Created new connection %r", connection)
#     903     self.fresh = True
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\engine\create.py:636, in create_engine.<locals>.connect(connection_record)
#     633         if connection is not None:
#     634             return connection
# --> 636 return dialect.connect(*cargs, **cparams)
#
# File c:\Users\se2p0\OneDrive\마케팅 공용 2\vscode\.venv\Lib\site-packages\sqlalchemy\engine\default.py:580, in DefaultDialect.connect(self, *cargs, **cparams)
#     578 def connect(self, *cargs, **cparams):
#     579     # inherits the docstring from interfaces.Dialect.connect
# --> 580     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File src\pymssql\_pymssql.pyx:653, in pymssql._pymssql.connect()
#
# OperationalError: (pymssql._pymssql.OperationalError) (20002, b'DB-Lib error message 20002, severity 9:\nAdaptive Server connection failed (192.168.10.27)\nDB-Lib error message 20002, severity 9:\nAdaptive Server connection failed (192.168.10.27)\n')
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# Table 생성 테스트

from sqlalchemy.types import NVARCHAR, DATE, Integer
dataTypeList = [NVARCHAR]*(len(df.columns)-1)
columnList = list(df.columns)
dTypeDict = dict(zip(columnList, dataTypeList))
dTypeDict['일자'] = DATE
dTypeDict['단가'] = Integer
dTypeDict['공급가'] = Integer
dTypeDict['합계'] = Integer
dTypeDict['수량'] = Integer

df = sales_all
conn = engine.connect()
df.to_sql(name='sales_sample', con=engine,
          if_exists='replace', index=False, dtype=dTypeDict)
conn.close()
sales_sample = pd.read_sql_table('sales_sample', con=engine)
# Out:
# 구분                                    본사
# 일자                   2014-04-08 00:00:00
# 품목구분                                [제품]
# 품목코드                          FBP-000014
# 품목명        TFB-G29ES 1Φ 220V 60HZ [Φ250]
# 최신 품목명    ●TFB-G29ES[Φ250] 1Φ 220V, 60HZ
# 규격                             TFB-G29ES
# 수량                                     1
# 단위                                    EA
# 단가                                134000
# 공급가                               134000
# 합계                                147400
# 거래처코드                              20062
# 거래처                                 동북산업
# 거래처그룹1                            영업_대리점
# 거래처그룹2                             영업_산업
# 담당자                                  윤형설
# 개설연도                              2006이전
# 지역구분                            인천광역시 동구
# 인센가입                                  적용
# 품목그룹1                            10_시로코팬
# 품목그룹2                          A2_소형시로코팬
# 인센품목                                   Y
# Name: 0, dtype: object

# %%
# 조건에 해당하는 데이터 뽑기
newdf = sales_sample[sales_sample['단가'] > 1000000]
newdf.to_excel('sample.xlsx')

# %%
import pymssql

# DB 서버 주소
server = 'FZ_SA_DGKIM'
# 데이터 베이스 이름
database = 'dbo.sales_main'
# 접속 유저명
username = 'se2p00'
# 접속 유저 패스워드
password = 'rmeo9821'


# MSSQL 접속
cnxn = pymssql.connect(server, username, password, database)
cursor = cnxn.cursor()

# SQL문 실행
cursor.execute('SELECT * FROM dbo.sales_all;')
